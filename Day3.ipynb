# %% [markdown]
# # DataFrame Handling

# %% [markdown]
# ## DataFrame 생성하기

# %%
import pandas as pd
import numpy as np

# %%
num3 = [
    [1,2,3],
    [4,5,6],
    [7,8,9],
]
num3
# Out:
# [[1, 2, 3], [4, 5, 6], [7, 8, 9]]

# %%
pd.DataFrame(num3)
# Out:
#    0  1  2
# 0  1  2  3
# 1  4  5  6
# 2  7  8  9

# %%
table1 = [
    ['2019-01-05',1000,'False','Gum'],
    ['2019-01-03',3000,'True',"snack"],
    ['2019-01-06',2000,'True',"beverage"],
    ['2019-01-06',1000,'True',"Gum"],
]
pd.DataFrame(table1)
# Out:
#             0     1      2         3
# 0  2019-01-05  1000  False       Gum
# 1  2019-01-03  3000   True     snack
# 2  2019-01-06  2000   True  beverage
# 3  2019-01-06  1000   True       Gum

# %%
pd.DataFrame(table1,columns=['일자','가격','구매여부','제품'])
# Out:
#            일자    가격   구매여부        제품
# 0  2019-01-05  1000  False       Gum
# 1  2019-01-03  3000   True     snack
# 2  2019-01-06  2000   True  beverage
# 3  2019-01-06  1000   True       Gum

# %%
colname = ['일자','가격','구매여부','제품']
df1 = pd.DataFrame(table1,columns=colname,index = ['A','B','C','D'])
df1
# Out:
#            일자    가격   구매여부        제품
# A  2019-01-05  1000  False       Gum
# B  2019-01-03  3000   True     snack
# C  2019-01-06  2000   True  beverage
# D  2019-01-06  1000   True       Gum

# %%
table2 = {
    '일자':['2019-01-01','2019-02-03','2019-02-04'],
    '가격':[200,3000,4000]
}
pd.DataFrame(table2)    #쌍반점 ':' !!
# Out:
#            일자    가격
# 0  2019-01-01   200
# 1  2019-02-03  3000
# 2  2019-02-04  4000

# %% [markdown]
# # Data Info

# %%
df1.columns
# Out:
# Index(['일자', '가격', '구매여부', '제품'], dtype='object')

# %%
df1.index
# Out:
# Index(['A', 'B', 'C', 'D'], dtype='object')

# %%
df1.values       #많이 사용되지 않음
# Out:
# array([['2019-01-05', 1000, 'False', 'Gum'],
#        ['2019-01-03', 3000, 'True', 'snack'],
#        ['2019-01-06', 2000, 'True', 'beverage'],
#        ['2019-01-06', 1000, 'True', 'Gum']], dtype=object)

# %%
df1.head(5)
# Out:
#            일자    가격   구매여부        제품
# A  2019-01-05  1000  False       Gum
# B  2019-01-03  3000   True     snack
# C  2019-01-06  2000   True  beverage
# D  2019-01-06  1000   True       Gum

# %%
df1.tail(2)
# Out:
#            일자    가격  구매여부        제품
# C  2019-01-06  2000  True  beverage
# D  2019-01-06  1000  True       Gum

# %%
df1['제품']     #Series 형태로 출력됨
# Out:
# A         Gum
# B       snack
# C    beverage
# D         Gum
# Name: 제품, dtype: object

# %%
df1[['제품','일자']] #DataFrame 형태로 출력됨
# Out:
#          제품          일자
# A       Gum  2019-01-05
# B     snack  2019-01-03
# C  beverage  2019-01-06
# D       Gum  2019-01-06

# %%
df1.info()   #pandas로 구성돼있고, A-D까지 구성돼있고, ....    not-null X missing Data가 없다(?)    DB missing data - 통계적 연산할때 사용
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 4 entries, A to D
# Data columns (total 4 columns):
# 일자      4 non-null object
# 가격      4 non-null int64
# 구매여부    4 non-null object
# 제품      4 non-null object
# dtypes: int64(1), object(3)
# memory usage: 320.0+ bytes

# %% [markdown]
# # sorting
# * 데이터를 순서대로 정리하는 것

# %%
df1
# Out:
#            일자    가격   구매여부        제품
# A  2019-01-05  1000  False       Gum
# B  2019-01-03  3000   True     snack
# C  2019-01-06  2000   True  beverage
# D  2019-01-06  1000   True       Gum

# %%
df1.sort_index()
# Out:
#            일자    가격   구매여부        제품
# A  2019-01-05  1000  False       Gum
# B  2019-01-03  3000   True     snack
# C  2019-01-06  2000   True  beverage
# D  2019-01-06  1000   True       Gum

# %%
df1.sort_index(axis=1)  #축을 1로 잡아주면 index순서가 아니라 column 순서대로 정리 할 수 있음
# Out:
#      가격   구매여부          일자        제품
# A  1000  False  2019-01-05       Gum
# B  3000   True  2019-01-03     snack
# C  2000   True  2019-01-06  beverage
# D  1000   True  2019-01-06       Gum

# %%
df1.sort_index(axis=1,ascending = False)    #뒤에서 부터 가져옴 내림차순으로
# Out:
#          제품          일자   구매여부    가격
# A       Gum  2019-01-05  False  1000
# B     snack  2019-01-03   True  3000
# C  beverage  2019-01-06   True  2000
# D       Gum  2019-01-06   True  1000

# %%
df1.sort_values(by='일자')    #날짜 순으로 가져올 수 있다
# Out:
#            일자    가격   구매여부        제품
# B  2019-01-03  3000   True     snack
# A  2019-01-05  1000  False       Gum
# C  2019-01-06  2000   True  beverage
# D  2019-01-06  1000   True       Gum

# %%
df1.sort_values(by='일자',ascending=False).head(2)    #내림차순 2개
# Out:
#            일자    가격  구매여부        제품
# C  2019-01-06  2000  True  beverage
# D  2019-01-06  1000  True       Gum

# %%
df1.sort_values(by=['가격','일자'],ascending=[False,True])  #가격은 내림차순(가격 ->False) , 일자는 오름차순 (일자 ->True)
# Out:
#            일자    가격   구매여부        제품
# B  2019-01-03  3000   True     snack
# C  2019-01-06  2000   True  beverage
# A  2019-01-05  1000  False       Gum
# D  2019-01-06  1000   True       Gum

# %% [markdown]
# # Operator

# %%
df1.mean()     #가격밖에 연속형자료가 없기 때문에 가격만 나옴
# Out:
# 가격    1750.0
# dtype: float64

# %%
df1['가격'].mean()
# Out:
# 1750.0

# %%
df1.min()
# Out:
# 일자      2019-01-03
# 가격            1000
# 구매여부         False
# 제품             Gum
# dtype: object

# %%
df1.max()
# Out:
# 일자      2019-01-06
# 가격            3000
# 구매여부          True
# 제품           snack
# dtype: object

# %%
df1['가격'].max()
# Out:
# 3000

# %%
df1.describe() #DataFrame 형태 #연속형 자료에 대한 모든 요약 정리를 해줌 / 갯수, 평균 , 표준편차, 최솟값,25%에 있는 데이터 , ...
# Out:
#                 가격
# count     4.000000
# mean   1750.000000
# std     957.427108
# min    1000.000000
# 25%    1000.000000
# 50%    1500.000000
# 75%    2250.000000
# max    3000.000000

# %%
df1['가격'].describe()    #Series 형태
# Out:
# count       4.000000
# mean     1750.000000
# std       957.427108
# min      1000.000000
# 25%      1000.000000
# 50%      1500.000000
# 75%      2250.000000
# max      3000.000000
# Name: 가격, dtype: float64

# %%
df1['제품'].describe()   #연속형 자료가 아니어도 (명목형 자료) 요약 정리를 해줌
# Out:
# count       4
# unique      3
# top       Gum
# freq        2
# Name: 제품, dtype: object

# %%
df1['제품','일자','구매여부'].describe()  #여러개로 할 때 Series로 입력하면 에러가 남
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2656             try:
# -> 2657                 return self._engine.get_loc(key)
#    2658             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: ('제품', '일자', '구매여부')
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-55-c627edf89b4d> in <module>
# ...

# %%
df1[['제품','일자','구매여부']].describe()   #DataFrame 으로 입력을 해주어야 함
# Out:
#          제품          일자  구매여부
# count     4           4     4
# unique    3           3     2
# top     Gum  2019-01-06  True
# freq      2           2     3

# %%
obj1 = ['제품','일자','구매여부']
df1[obj1].describe()    #이렇게하면 편하게 사용 가능
# Out:
#          제품          일자  구매여부
# count     4           4     4
# unique    3           3     2
# top     Gum  2019-01-06  True
# freq      2           2     3

# %%
df1['제품'].value_counts().sort_values(ascending=False).head(2)     #원하는 데이터만 다 이어서 붙일 수 있음
# Out:
# Gum      2
# snack    1
# Name: 제품, dtype: int64

# %% [markdown]
# # Indexing

# %% [markdown]
# * 특정 위치에 있는 데이터를 찾아올 때 사용

# %%
df1['제품']
# Out:
# A         Gum
# B       snack
# C    beverage
# D         Gum
# Name: 제품, dtype: object

# %%
df1[['제품','일자']]
# Out:
#          제품          일자
# A       Gum  2019-01-05
# B     snack  2019-01-03
# C  beverage  2019-01-06
# D       Gum  2019-01-06

# %% [markdown]
# * location -> 특정 위치에 있는 데이터를 가져온다

# %%
df1.loc['B']
# Out:
# 일자      2019-01-03
# 가격            3000
# 구매여부          True
# 제품           snack
# Name: B, dtype: object

# %%
df1.loc[['A','D']]
# Out:
#            일자    가격   구매여부   제품
# A  2019-01-05  1000  False  Gum
# D  2019-01-06  1000   True  Gum

# %%
df1.loc['A':'D']   #A~D까지 가져옴
# Out:
#            일자    가격   구매여부        제품
# A  2019-01-05  1000  False       Gum
# B  2019-01-03  3000   True     snack
# C  2019-01-06  2000   True  beverage
# D  2019-01-06  1000   True       Gum

# %%
df1['가격']['B']   #값만 가져올 수 있음
# Out:
# 3000

# %%
df1.iloc[0:2]       #위치기반 location   /  loc 항목기반 location
# Out:
#            일자    가격   구매여부     제품
# A  2019-01-05  1000  False    Gum
# B  2019-01-03  3000   True  snack

# %%
#loc는 항목을 써줘야되고 , iloc는 matarix형태로 인지 해서 0~2데이터를 가져온다

# %%
df1.iloc[0,2]    #0,2항목에 대한 데이터
# Out:
# 'False'

# %% [markdown]
# * 비교연산을 이용한 Indexing

# %%
df1['가격'] > 2000
# Out:
# A    False
# B     True
# C    False
# D    False
# Name: 가격, dtype: bool

# %%
df1[df1['가격'] > 2000]    #2000원 이상의 데이터만 데이터 프레임 형태로 가져옴
# Out:
#            일자    가격  구매여부     제품
# B  2019-01-03  3000  True  snack

# %%
df1[df1['제품'] == 'Gum']
# Out:
#            일자    가격   구매여부   제품
# A  2019-01-05  1000  False  Gum
# D  2019-01-06  1000   True  Gum

# %%
df1[(df1['제품'] == 'Gum')&(df1['구매여부']=='True')]
# Out:
#            일자    가격  구매여부   제품
# D  2019-01-06  1000  True  Gum

# %% [markdown]
# * and : &
# * or : | shift + \

# %%
condition1 = (df1['제품']=='Gum')
condition2 = (df1['구매여부']=='True')
df1[condition1|condition2]
# Out:
#            일자    가격   구매여부        제품
# A  2019-01-05  1000  False       Gum
# B  2019-01-03  3000   True     snack
# C  2019-01-06  2000   True  beverage
# D  2019-01-06  1000   True       Gum

# %%
df1[condition1&condition2]
# Out:
#            일자    가격  구매여부   제품
# D  2019-01-06  1000  True  Gum

# %%
df1[df1['제품']!='Gum']
# Out:
#            일자    가격  구매여부        제품
# B  2019-01-03  3000  True     snack
# C  2019-01-06  2000  True  beverage

# %%
df1['제품'].isin(['snack'])        #isin => 제품이라는 데이터 안에 snack 이 있냐 없냐
# Out:
# A    False
# B     True
# C    False
# D    False
# Name: 제품, dtype: bool

# %%
df1[df1['제품'].isin(['snack', 'Gum'])]     #  == 표시를 계속 쓰기 힘드니까 isin을 사용함
# Out:
#            일자    가격   구매여부     제품
# A  2019-01-05  1000  False    Gum
# B  2019-01-03  3000   True  snack
# D  2019-01-06  1000   True    Gum

# %%
df1[~df1['제품'].isin(['snack', 'Gum'])]   #snack이랑 Gum이 없는 자료를 가져오고 싶다 -->  '~' 사용!!
                                           #but and 조건 이용할 때 주의해야함 and도 or로 뒤집힘
# Out:
#            일자    가격  구매여부        제품
# C  2019-01-06  2000  True  beverage

# %% [markdown]
# # Add/Edit/Delete

# %%
df1['환불여부'] = '정상'

# %%
df1
# Out:
#            일자    가격   구매여부        제품 환불여부
# A  2019-01-05  1000  False       Gum   정상
# B  2019-01-03  3000   True     snack   정상
# C  2019-01-06  2000   True  beverage   정상
# D  2019-01-06  1000   True       Gum   정상

# %%
df1['환불여부'] = ['정상','환불','환불','정상']   #데이터 갯수 맞춰주지 않으면 에러남
df1
# Out:
#            일자    가격   구매여부        제품 환불여부
# A  2019-01-05  1000  False       Gum   정상
# B  2019-01-03  3000   True     snack   환불
# C  2019-01-06  2000   True  beverage   환불
# D  2019-01-06  1000   True       Gum   정상

# %%
codition1 = (df1['구매여부'] == 'True') & (df1['환불여부']=='환불')
df1.loc[condition1, '판매여부'] = False   #loc함수를 이용해서 새로운 DataFrame을 만들어줌 
df1.loc[~condition1, '판매여부'] = True
df1
# Out:
#            일자    가격   구매여부        제품 환불여부   판매여부
# A  2019-01-05  1000  False       Gum   정상  False
# B  2019-01-03  3000   True     snack   환불   True
# C  2019-01-06  2000   True  beverage   환불   True
# D  2019-01-06  1000   True       Gum   정상  False

# %%
 df1.info()   #판매여부에 missing data가 2개밖에 없다
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 4 entries, A to D
# Data columns (total 6 columns):
# 일자      4 non-null object
# 가격      4 non-null int64
# 구매여부    4 non-null object
# 제품      4 non-null object
# 환불여부    4 non-null object
# 판매여부    2 non-null object
# dtypes: int64(1), object(5)
# memory usage: 384.0+ bytes

# %%
df1['가격(clean)']= df1['가격']*2
df1
# Out:
#            일자    가격   구매여부        제품 환불여부   판매여부  가격(clean)
# A  2019-01-05  1000  False       Gum   정상  False       2000
# B  2019-01-03  3000   True     snack   환불   True       6000
# C  2019-01-06  2000   True  beverage   환불   True       4000
# D  2019-01-06  1000   True       Gum   정상  False       2000

# %%
df1['가격(clean)']=df1['가격'].mean()
df1
# Out:
#            일자    가격   구매여부        제품 환불여부   판매여부  가격(clean)
# A  2019-01-05  1000  False       Gum   정상  False     1750.0
# B  2019-01-03  3000   True     snack   환불   True     1750.0
# C  2019-01-06  2000   True  beverage   환불   True     1750.0
# D  2019-01-06  1000   True       Gum   정상  False     1750.0

# %%
df2 = df1.drop('가격(clean)',axis=1)     #drop : 기존의 데이터를 index나 column중심으로 삭제 
df2                                      #하지만 아직 df1에는 '가격(clean)'이 살아있음
                                         #drop 은 그냥 눈에서만 안보이게 해주는 것
# Out:
#            일자    가격   구매여부        제품 환불여부   판매여부
# A  2019-01-05  1000  False       Gum   정상  False
# B  2019-01-03  3000   True     snack   환불   True
# C  2019-01-06  2000   True  beverage   환불   True
# D  2019-01-06  1000   True       Gum   정상  False

# %%
df1.drop('가격(clean)',axis=1, inplace = True)    #inplace = True -> 진짜 column 자체에서 삭제를 시켜줌 inplace  (잘 안씀)
# Out:
#            일자    가격   구매여부        제품 환불여부   판매여부
# A  2019-01-05  1000  False       Gum   정상  False
# B  2019-01-03  3000   True     snack   환불   True
# C  2019-01-06  2000   True  beverage   환불   True
# D  2019-01-06  1000   True       Gum   정상  False

# %%
df1.drop(['가격(clean)','판매여부'].axis=1.inplace=True)   #가격이 이미 삭제돼서 오류로 뜸
# Out:
#   File "<ipython-input-117-5f8d1508888a>", line 1
#     df1.drop(['가격(clean)','판매여부'].axis=1.inplace=True)
#                                                ^
# SyntaxError: invalid syntax

# %%
df1['환불여부(clean)'] = df1['환불여부'].replace('정상',1).replace('환불',0)
df1
# Out:
#            일자    가격   구매여부        제품 환불여부   판매여부  가격(clean)  환불여부(clean)
# A  2019-01-05  1000  False       Gum   정상  False     1750.0            1
# B  2019-01-03  3000   True     snack   환불   True     1750.0            0
# C  2019-01-06  2000   True  beverage   환불   True     1750.0            0
# D  2019-01-06  1000   True       Gum   정상  False     1750.0            1

# %% [markdown]
# # Data Load

# %%
url_data = 'http://46.101.230.157/dilan/pandas_tutorial_read.csv'
df2 = pd.read_csv(url_data, delimiter = ';',header = None,
                 names= ['datatime','event','country','user_id','source','topic']) #;을 바꿔줌 ,으로 인식을해서 원래 #header를 숫자로 바꿔주고 다시 이름 붙여줌
df2
# Out:
#                  datatime event    country     user_id   source          topic
# 0     2018-01-01 00:01:01  read  country_7  2458151261      SEO  North America
# 1     2018-01-01 00:03:20  read  country_7  2458151262      SEO  South America
# 2     2018-01-01 00:04:01  read  country_7  2458151263  AdWords         Africa
# 3     2018-01-01 00:04:02  read  country_7  2458151264  AdWords         Europe
# 4     2018-01-01 00:05:03  read  country_8  2458151265   Reddit  North America
# 5     2018-01-01 00:05:42  read  country_6  2458151266   Reddit  North America
# 6     2018-01-01 00:06:06  read  country_2  2458151267   Reddit         Europe
# 7     2018-01-01 00:06:15  read  country_6  2458151268  AdWords         Europe
# 8     2018-01-01 00:07:21  read  country_7  2458151269  AdWords  North America
# 9     2018-01-01 00:07:29  read  country_5  2458151270   Reddit  North America
# 10    2018-01-01 00:07:57  read  country_5  2458151271  AdWords           Asia
# ...

# %%
#df1 = pd.read_csv('store_market_data.csv',engine = 'python',encoding = 'utf-8')    #경로상에 한글이름이 있으면 engine 써주면 됨
df1 = pd.read_csv('store_market_data.csv')
df1
# Out:
#               공급일자 요일  공급월  공급주차        회원번호 조합원상태  물품대분류    물품중분류     물품소분류  \
# 0       2018-01-02  화    1     1   272369856  정상회원     과실       과일        사과
# 1       2018-01-02  화    1     1  1506656256  정상회원     채소       버섯     느타리버섯
# 2       2018-01-02  화    1     1  1506656256  정상회원    축산물        알       유정란
# 3       2018-01-02  화    1     1  1023108864  정상회원     반찬    두부/유부        두부
# 4       2018-01-02  화    1     1  1476143616  정상회원     간식        빵  식빵, 식사대용
# 5       2018-01-02  화    1     1   716128320  정상회원    축산물        알       유정란
# 6       2018-01-02  화    1     1   743192512  정상회원     채소     과일채소        딸기
# 7       2018-01-02  화    1     1   743192512  정상회원     채소   잎/줄기채소     어린잎채소
# 8       2018-01-02  화    1     1   743192512  정상회원     채소     양념채소        생강
# 9       2018-01-02  화    1     1   743192512  정상회원     채소     쌈채소류       쌈케일
# 10      2018-01-02  화    1     1  1177875136  정상회원     채소     뿌리채소        연근
# ...

# %% [markdown]
# # Group by

# %%
df1.head()     #데이터를 붙인 데이터 바코드를 찍히면 찍힌 데이터만 있어야 되는데 추가로 붙여준 것
# Out:
#          공급일자 요일  공급월  공급주차        회원번호 조합원상태 물품대분류  물품중분류     물품소분류  \
# 0  2018-01-02  화    1     1   272369856  정상회원    과실     과일        사과
# 1  2018-01-02  화    1     1  1506656256  정상회원    채소     버섯     느타리버섯
# 2  2018-01-02  화    1     1  1506656256  정상회원   축산물      알       유정란
# 3  2018-01-02  화    1     1  1023108864  정상회원    반찬  두부/유부        두부
# 4  2018-01-02  화    1     1  1476143616  정상회원    간식      빵  식빵, 식사대용
#
#                 물품명  구매수량 주소-구  주소-동 성별    연령    연령대   구매금액 구매매장  반품_원거래일자  \
# 0       사과/유(1.5kg)   1.0  수지구  풍덕천동  여  45.0    40대  22207  매장C       NaN
# 1       느타리버섯(300g)   1.0  수지구  풍덕천동  여  36.0  30대이하   4977  매장C       NaN
# 2  유정란/매장용(10알/국내산)   1.0  수지구  풍덕천동  여  36.0  30대이하   7083  매장C       NaN
# 3         연두부(100g)   1.0  수지구  풍덕천동  여  36.0  30대이하    766  매장C       NaN
# 4   아침빵(240g/8개)/매장   1.0  수지구  풍덕천동  여  34.0  30대이하   4403  매장C       NaN
#
#     구매시각
# 0  10:04
# 1  10:05
# 2  10:05
# 3  10:08
# 4  10:09

# %%
df1.groupby('요일').mean()    #요일별로 연속별 항목에 대해서 평균을 취해줌   #pivoting할 때 groupby를 사용함
# Out:
#          공급월       공급주차          회원번호      구매수량         연령          구매금액  \
# 요일
# 금   3.679024  13.909721  7.366242e+08  1.138407  50.968497  11064.344340
# 목   3.570806  13.614572  7.317310e+08  1.129928  51.099647  10857.069337
# 수   3.292904  12.790732  7.434917e+08  1.144800  50.733620  11062.047300
# 월   3.521324  14.006212  7.508196e+08  1.131904  50.381287  10542.528917
# 일   3.572221  13.222756  7.566981e+08  1.144827  50.118775  10939.249736
# 토   3.558841  13.502375  7.203877e+08  1.148571  50.972849  11046.589839
# 화   3.410518  13.226825  7.388714e+08  1.134223  50.783786  11002.352378
#
#         반품_원거래일자
# 요일
# 금   2.018037e+07
# 목   2.018032e+07
# 수   2.018035e+07
# 월   2.018038e+07
# 일   2.018030e+07
# 토   2.018036e+07
# 화   2.018030e+07

# %%
df1.groupby('요일')['구매금액'].mean()
# Out:
# 요일
# 금    11064.344340
# 목    10857.069337
# 수    11062.047300
# 월    10542.528917
# 일    10939.249736
# 토    11046.589839
# 화    11002.352378
# Name: 구매금액, dtype: float64

# %%
df1.groupby('공급월')['구매금액'].sum()
# Out:
# 공급월
# 1    1315877825
# 2    1338145789
# 3    1301065553
# 4    1214161970
# 5    1270090983
# 6    1265520070
# Name: 구매금액, dtype: int64

# %%
df1.groupby(['요일','연령대'])['구매금액'].sum()
# Out:
# 요일  연령대
# 금   30대이하    158434038
#     40대      449759043
#     50대      319196997
#     60대      170808002
#     70대이상    117390184
# 목   30대이하    150301936
#     40대      416901325
#     50대      293524482
#     60대      157682379
#     70대이상    112148947
# 수   30대이하    156665842
#     40대      436644537
#     50대      298765854
#     60대      168640554
#     70대이상    100567716
# 월   30대이하    195332433
#     40대      502023099
#     50대      306132225
#     60대      189428259
#     70대이상    112213387
# 일   30대이하     88129516
#     40대      219118519
#     50대      162602594
#     60대       79819775
#     70대이상     41891404
# 토   30대이하    139605909
#     40대      392879470
#     50대      315820204
#     60대      135737196
#     70대이상     92900311
# 화   30대이하    159659515
#     40대      459077946
#     50대      324727130
#     60대      175776657
#     70대이상    104139379
# Name: 구매금액, dtype: int64

# %%
#보통 주차별로 보는 걸 좋아함

# %% [markdown]
# ** Pivot_Talbe  :  trend를 파악할 수 있음

# %%
pd.pivot_table(data = df1, index='공급주차',values = '구매금액', aggfunc='sum')  #DataFrame으로 이쁘게 뽑을 수 있음
# Out:
#            구매금액
# 공급주차
# 1     257420782
# 2     295452388
# 3     301333035
# 4     319554190
# 5     312613161
# 6     382359856
# 7     367806188
# 8     287153989
# 9     302163801
# 10    285387054
# 11    276131848
# 12    300137276
# 13    289066238
# 14    282649742
# 15    288567775
# 16    285117000
# 17    288347633
# 18    260039148
# 19    301432526
# 20    283186659
# 21    288863541
# 22    300186805
# 23    287356193
# 24    272863307
# 25    293003945
# 26    296668110

# %%
result1 = pd.pivot_table(data = df1, index=['요일','연령대'],values = '구매금액', aggfunc='sum')  #요일별 연령대별 구매금액 총합
result1
# Out:
#                구매금액
# 요일 연령대
# 금  30대이하  158434038
#    40대    449759043
#    50대    319196997
#    60대    170808002
#    70대이상  117390184
# 목  30대이하  150301936
#    40대    416901325
#    50대    293524482
#    60대    157682379
#    70대이상  112148947
# 수  30대이하  156665842
#    40대    436644537
#    50대    298765854
#    60대    168640554
#    70대이상  100567716
# 월  30대이하  195332433
#    40대    502023099
#    50대    306132225
#    60대    189428259
#    70대이상  112213387
# 일  30대이하   88129516
#    40대    219118519
#    50대    162602594
#    60대     79819775
#    70대이상   41891404
# 토  30대이하  139605909
#    40대    392879470
#    50대    315820204
#    60대    135737196
#    70대이상   92900311
# 화  30대이하  159659515
#    40대    459077946
#    50대    324727130
#    60대    175776657
#    70대이상  104139379

# %%
pd.pivot_table(data = df1, index=['요일','연령대'],values = '구매금액', aggfunc='sum').T  #T를 써주면 옆으로 눞혀줌
# Out:
# 요일            금                                                      목  \
# 연령대       30대이하        40대        50대        60대      70대이상      30대이하
# 구매금액  158434038  449759043  319196997  170808002  117390184  150301936
#
# 요일                                                ...          토             \
# 연령대         40대        50대        60대      70대이상  ...      30대이하        40대
# 구매금액  416901325  293524482  157682379  112148947  ...  139605909  392879470
#
# 요일                                            화                        \
# 연령대         50대        60대     70대이상      30대이하        40대        50대
# 구매금액  315820204  135737196  92900311  159659515  459077946  324727130
#
# 요일
# 연령대         60대      70대이상
# 구매금액  175776657  104139379
#
# [1 rows x 35 columns]

# %%
result1 = pd.pivot_table(data = df1, index=['요일','연령대'],values = '구매금액', aggfunc='sum')  #요일별 연령대별 구매금액 총합
result1.reset_index()
# Out:
#    요일    연령대       구매금액
# 0   금  30대이하  158434038
# 1   금    40대  449759043
# 2   금    50대  319196997
# 3   금    60대  170808002
# 4   금  70대이상  117390184
# 5   목  30대이하  150301936
# 6   목    40대  416901325
# 7   목    50대  293524482
# 8   목    60대  157682379
# 9   목  70대이상  112148947
# 10  수  30대이하  156665842
# 11  수    40대  436644537
# 12  수    50대  298765854
# 13  수    60대  168640554
# 14  수  70대이상  100567716
# 15  월  30대이하  195332433
# 16  월    40대  502023099
# 17  월    50대  306132225
# 18  월    60대  189428259
# 19  월  70대이상  112213387
# 20  일  30대이하   88129516
# 21  일    40대  219118519
# 22  일    50대  162602594
# 23  일    60대   79819775
# 24  일  70대이상   41891404
# 25  토  30대이하  139605909
# 26  토    40대  392879470
# 27  토    50대  315820204
# 28  토    60대  135737196
# 29  토  70대이상   92900311
# 30  화  30대이하  159659515
# 31  화    40대  459077946
# 32  화    50대  324727130
# 33  화    60대  175776657
# 34  화  70대이상  104139379

# %%
result1 = pd.pivot_table(data = df1, index=['요일','연령대'],values = '구매금액', aggfunc='sum')  #요일별 연령대별 구매금액 총합
result1.reset_index().sort_values(by='구매금액',ascending = False).head(3)                #python의 장점이 다 들어가있음
# Out:
#    요일  연령대       구매금액
# 16  월  40대  502023099
# 31  화  40대  459077946
# 1   금  40대  449759043

# %%
#pivot_tale 연습 많이 하기

# %%
#30년치 네이버 모든 뉴스기사 데이터 1GB

# %%
#Mapreduce - 여러개의 서버 컴퓨터로 나누고 한 곳으로 취합해서 처리함  --> 구글 검색속도가 빠른이유

# %%
#통계분석 Tool - R , Jmp(클릭으로 분석 할 수 있는 도구) ,파이썬을 제일 추천

# %% [markdown]
# # 데이터 시각화
#
# * EDA(탐색적 데이터 분석) : 시각화 분석

# %% [markdown]
# ## Matplot Lib
# * 그래프 출력할 때 쓰는 라이브러리 (코드가 너무김)
# * 그래프가 못생김
# * 그래프의 옵션을 줄 때 사용 (한글 출력 안될 때, 그래프 사이즈가 작을 때)
# * 디테일하게 하고싶을 때 사용

# %% [markdown]
# ## Seaborn
# * 직관적으로 빠르게 분석해줌
# * 그래프가 이쁘다
# * 그래프 출력할 때 사용

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt #그래프 출력시
import matplotlib as mpl #그래프 옵션

#그래프 시각화 옵션 설정 함수
# %matplotlib inline

#그래프 한글 설정
mpl.rc('font',family = 'Malgun Gothic') #컴퓨터 자체에 있는 글씨체를 불러온다 #C:\Windows\Fonts에서 찾아서 쓰면 됨

#그래프의 한글을 더욱 선명하게 출력
from IPython.display import set_matplotlib_formats
set_matplotlib_formats('retina')

#그래프에서 음수값이 나올 때, 깨지는 현상 방지
mpl.rc('axes', unicode_minus = False)

# %%
url = 'http://bitly.kr/ykYiM'
data = pd.read_csv(url)

# %%
data = pd.read_csv('store_market_data.csv')
data
# Out:
#               공급일자 요일  공급월  공급주차        회원번호 조합원상태  물품대분류    물품중분류     물품소분류  \
# 0       2018-01-02  화    1     1   272369856  정상회원     과실       과일        사과
# 1       2018-01-02  화    1     1  1506656256  정상회원     채소       버섯     느타리버섯
# 2       2018-01-02  화    1     1  1506656256  정상회원    축산물        알       유정란
# 3       2018-01-02  화    1     1  1023108864  정상회원     반찬    두부/유부        두부
# 4       2018-01-02  화    1     1  1476143616  정상회원     간식        빵  식빵, 식사대용
# 5       2018-01-02  화    1     1   716128320  정상회원    축산물        알       유정란
# 6       2018-01-02  화    1     1   743192512  정상회원     채소     과일채소        딸기
# 7       2018-01-02  화    1     1   743192512  정상회원     채소   잎/줄기채소     어린잎채소
# 8       2018-01-02  화    1     1   743192512  정상회원     채소     양념채소        생강
# 9       2018-01-02  화    1     1   743192512  정상회원     채소     쌈채소류       쌈케일
# 10      2018-01-02  화    1     1  1177875136  정상회원     채소     뿌리채소        연근
# ...

# %%
data.head()
# Out:
#          공급일자 요일  공급월  공급주차        회원번호 조합원상태 물품대분류  물품중분류     물품소분류  \
# 0  2018-01-02  화    1     1   272369856  정상회원    과실     과일        사과
# 1  2018-01-02  화    1     1  1506656256  정상회원    채소     버섯     느타리버섯
# 2  2018-01-02  화    1     1  1506656256  정상회원   축산물      알       유정란
# 3  2018-01-02  화    1     1  1023108864  정상회원    반찬  두부/유부        두부
# 4  2018-01-02  화    1     1  1476143616  정상회원    간식      빵  식빵, 식사대용
#
#                 물품명  구매수량 주소-구  주소-동 성별    연령    연령대   구매금액 구매매장  반품_원거래일자  \
# 0       사과/유(1.5kg)   1.0  수지구  풍덕천동  여  45.0    40대  22207  매장C       NaN
# 1       느타리버섯(300g)   1.0  수지구  풍덕천동  여  36.0  30대이하   4977  매장C       NaN
# 2  유정란/매장용(10알/국내산)   1.0  수지구  풍덕천동  여  36.0  30대이하   7083  매장C       NaN
# 3         연두부(100g)   1.0  수지구  풍덕천동  여  36.0  30대이하    766  매장C       NaN
# 4   아침빵(240g/8개)/매장   1.0  수지구  풍덕천동  여  34.0  30대이하   4403  매장C       NaN
#
#     구매시각
# 0  10:04
# 1  10:05
# 2  10:05
# 3  10:08
# 4  10:09

# %%
data.columns
# Out:
# Index(['공급일자', '요일', '공급월', '공급주차', '회원번호', '조합원상태', '물품대분류', '물품중분류', '물품소분류',
#        '물품명', '구매수량', '주소-구', '주소-동', '성별', '연령', '연령대', '구매금액', '구매매장',
#        '반품_원거래일자', '구매시각'],
#       dtype='object')

# %%
data.index
# Out:
# RangeIndex(start=0, stop=705571, step=1)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 705571 entries, 0 to 705570
# Data columns (total 20 columns):
# 공급일자        705571 non-null object
# 요일          705571 non-null object
# 공급월         705571 non-null int64
# 공급주차        705571 non-null int64
# 회원번호        705571 non-null int64
# 조합원상태       705571 non-null object
# 물품대분류       705571 non-null object
# 물품중분류       705571 non-null object
# 물품소분류       705571 non-null object
# 물품명         705571 non-null object
# 구매수량        705571 non-null float64
# 주소-구        705571 non-null object
# 주소-동        705571 non-null object
# 성별          705566 non-null object
# 연령          705538 non-null float64
# 연령대         705538 non-null object
# 구매금액        705571 non-null int64
# 구매매장        705571 non-null object
# 반품_원거래일자    11234 non-null float64
# 구매시각        705571 non-null object
# dtypes: float64(3), int64(4), object(13)
# memory usage: 107.7+ MB

# %%
data.describe()
# Out:
#                  공급월           공급주차          회원번호           구매수량  \
# count  705571.000000  705571.000000  7.055710e+05  705571.000000
# mean        3.510817      13.500022  7.390639e+08       1.138203
# std         1.719153       7.517818  4.251288e+08       0.754448
# min         1.000000       1.000000  1.876416e+07     -50.000000
# 25%         2.000000       7.000000  3.906917e+08       1.000000
# 50%         4.000000      13.000000  7.456573e+08       1.000000
# 75%         5.000000      20.000000  1.045186e+09       1.000000
# max         6.000000      26.000000  1.670621e+09      50.000000
#
#                   연령          구매금액      반품_원거래일자
# count  705538.000000  7.055710e+05  1.123400e+04
# mean       50.756234  1.092004e+04  2.018034e+07
# std        11.418854  1.670323e+04  5.229237e+02
# min         1.000000 -6.662160e+05  2.017121e+07
# 25%        42.000000  4.116000e+03  2.018021e+07
# 50%        49.000000  7.275000e+03  2.018040e+07
# ...

# %% [markdown]
# # Count Plot

# %%
sns.countplot(data['물품대분류'])

# %%
plt.figure(figsize=[10,5])
sns.countplot(data['물품대분류'])

# %%
plt.figure(figsize=[10,5])
sns.countplot(data = data, x = '요일', hue = '성별')

# %%
plt.figure(figsize=[7.5,3])
sns.countplot(data = data, x = '요일', hue = '성별',color = 'g')

# %%
plt.figure(figsize=[3.7,5])
sns.countplot(data = data, y = '요일', hue = '성별',color = 'r')

# %% [markdown]
# # Distplot
# * 확률 분포
# * histogram 을 같이 그려줄 수 있음

# %%
data.columns
# Out:
# Index(['공급일자', '요일', '공급월', '공급주차', '회원번호', '조합원상태', '물품대분류', '물품중분류', '물품소분류',
#        '물품명', '구매수량', '주소-구', '주소-동', '성별', '연령', '연령대', '구매금액', '구매매장',
#        '반품_원거래일자', '구매시각'],
#       dtype='object')

# %%
plt.figure(figsize = [7,3])
sns.distplot(data['구매금액'])   #선이 확률분포 #bar에 있는게 실제 데이터 = histogram

# %%
df2 = sns.load_dataset('fmri') #예제 데이터 이름
df2.head()
# Out:
#   subject  timepoint event    region    signal
# 0     s13         18  stim  parietal -0.017552
# 1      s5         14  stim  parietal -0.080883
# 2     s12         18  stim  parietal -0.081033
# 3     s11         18  stim  parietal -0.046134
# 4     s10         18  stim  parietal -0.037970

# %%
plt.figure(figsize=[7,3])
sns.distplot(df2['timepoint'])

# %%
plt.figure(figsize=[7,3])
sns.distplot(df2['timepoint'],hist=False)   #histogram은 빼고 확률분포만 보여줌

# %%
plt.figure(figsize=[7,3])
sns.distplot(df2['timepoint'],kde=False)

# %%
plt.figure(figsize=[7,3])
sns.distplot(df2['timepoint'],vertical = True)

# %% [markdown]
# # Bar & Box
# * count -> x:범주
# * dist -> x : 연속
# * bar/box -> x: 범주형 / y: 연속형

# %% [markdown]
# ## Bar plot

# %%
plt.figure(figsize=[10,3])
sns.barplot(data = data, x='물품대분류', y='구매금액')   #검은색 선 :  신뢰구간

# %%
plt.figure(figsize=[10,3])
plt.ylim([10000,20000])
sns.barplot(data = data, x='물품대분류', y='구매금액')

# %%
plt.figure(figsize=[10,3])
#plt.ylim([10000,20000])
sns.barplot(data = data, x='물품대분류', y='구매금액',estimator=sum)

# %% [markdown]
# ## Box plot

# %%
df2 =

# %%
plt.figure(figsize=[7,3])
sns.boxplot(data = df2,x='region',y='timepoint')    #신뢰구간 25% 50% 75% 선으로 나뉘어있음  그 위아래는 이상치

# %%
plt.figure(figsize=[7,3])
sns.boxplot(data = df2,x='subject',y='signal',hue='region')

# %%
plt.figure(figsize=[7,3])
sns.boxplot(data = df2,y='subject',x='signal', hue='region')   #실무에서 아주 많이 쓰임

# %% [markdown]
# # Point & Line Plot

# %%
plt.figure(figsize=[10,5])
sns.pointplot(data = data, x='공급주차',y= '구매금액')   #점이 찍혀있음

# %%
plt.figure(figsize=[10,5])
sns.lineplot(data = data, x='공급주차',y= '구매금액',hue = '물품대분류')     #선으로만 돼있음 #물품마다 판매추이를 볼 수 있음

# %% [markdown]
# # Violin Plot
# * 데이터의 분포를 나타내 줌

# %%
df2
# Out:
#      subject  timepoint event    region    signal
# 0        s13         18  stim  parietal -0.017552
# 1         s5         14  stim  parietal -0.080883
# 2        s12         18  stim  parietal -0.081033
# 3        s11         18  stim  parietal -0.046134
# 4        s10         18  stim  parietal -0.037970
# 5         s9         18  stim  parietal -0.103513
# 6         s8         18  stim  parietal -0.064408
# 7         s7         18  stim  parietal -0.060526
# 8         s6         18  stim  parietal -0.007029
# 9         s5         18  stim  parietal -0.040557
# 10        s4         18  stim  parietal -0.048812
# 11        s3         18  stim  parietal -0.047148
# 12        s2         18  stim  parietal -0.086623
# 13        s1         18  stim  parietal -0.046659
# 14        s0         18  stim  parietal -0.075570
# 15       s13         17  stim  parietal -0.008265
# 16       s12         17  stim  parietal -0.088512
# 17        s7          9  stim  parietal  0.058897
# ...

# %%
plt.figure(figsize=[10,5]) 
sns.violinplot(data = df2 , x='region',y= 'signal')    #데이터에 대한 분포를 옆으로 눞혀서 생성

# %%
plt.figure(figsize=[10,10])                      #다시보기 
sns.violinplot(data = df2 , x='signal',y='subject',hue= 'signal')

# %% [markdown]
# # Scatter Plot 산전도

# %%
plt.figure(figsize=[10,10])   #size 크게 잡아주면 라벨 위치 잘 잡을 수 있음 
sns.scatterplot(data=df2, x='timepoint',y='signal',hue= 'subject', size= 'region')  #연속형자료에서 점형태로

# %% [markdown]
# # Exercise

# %%
df1 = pd.read_csv('store_market_data.csv')

# %%
df1.head()
# Out:
#          공급일자 요일  공급월  공급주차        회원번호 조합원상태 물품대분류  물품중분류     물품소분류  \
# 0  2018-01-02  화    1     1   272369856  정상회원    과실     과일        사과
# 1  2018-01-02  화    1     1  1506656256  정상회원    채소     버섯     느타리버섯
# 2  2018-01-02  화    1     1  1506656256  정상회원   축산물      알       유정란
# 3  2018-01-02  화    1     1  1023108864  정상회원    반찬  두부/유부        두부
# 4  2018-01-02  화    1     1  1476143616  정상회원    간식      빵  식빵, 식사대용
#
#                 물품명  구매수량 주소-구  주소-동 성별    연령    연령대   구매금액 구매매장  반품_원거래일자  \
# 0       사과/유(1.5kg)   1.0  수지구  풍덕천동  여  45.0    40대  22207  매장C       NaN
# 1       느타리버섯(300g)   1.0  수지구  풍덕천동  여  36.0  30대이하   4977  매장C       NaN
# 2  유정란/매장용(10알/국내산)   1.0  수지구  풍덕천동  여  36.0  30대이하   7083  매장C       NaN
# 3         연두부(100g)   1.0  수지구  풍덕천동  여  36.0  30대이하    766  매장C       NaN
# 4   아침빵(240g/8개)/매장   1.0  수지구  풍덕천동  여  34.0  30대이하   4403  매장C       NaN
#
#     구매시각
# 0  10:04
# 1  10:05
# 2  10:05
# 3  10:08
# 4  10:09

# %%
df1.isnull()  #각항목에 데이터가 들어가있는 지 없는지 확인 해주는 것   missing data 확인 할 때
# Out:
#          공급일자     요일    공급월   공급주차   회원번호  조합원상태  물품대분류  물품중분류  물품소분류    물품명  \
# 0       False  False  False  False  False  False  False  False  False  False
# 1       False  False  False  False  False  False  False  False  False  False
# 2       False  False  False  False  False  False  False  False  False  False
# 3       False  False  False  False  False  False  False  False  False  False
# 4       False  False  False  False  False  False  False  False  False  False
# 5       False  False  False  False  False  False  False  False  False  False
# 6       False  False  False  False  False  False  False  False  False  False
# 7       False  False  False  False  False  False  False  False  False  False
# 8       False  False  False  False  False  False  False  False  False  False
# 9       False  False  False  False  False  False  False  False  False  False
# 10      False  False  False  False  False  False  False  False  False  False
# ...

# %%
df1.isnull().sum()   #진짜 많이 사용함  missing data 확인할 때
# Out:
# 공급일자             0
# 요일               0
# 공급월              0
# 공급주차             0
# 회원번호             0
# 조합원상태            0
# 물품대분류            0
# 물품중분류            0
# 물품소분류            0
# 물품명              0
# 구매수량             0
# 주소-구             0
# 주소-동             0
# 성별               5
# 연령              33
# 연령대             33
# 구매금액             0
# 구매매장             0
# 반품_원거래일자    694337
# 구매시각             0
# dtype: int64

# %%
result1 = pd.pivot_table(data=df1, index='물품대분류',values = '구매수량',aggfunc='sum')
result2 = result1.reset_index().sort_values(by='구매수량',ascending = False).head() #인덱스 재배치, 내림차순
result2
# Out:
#    물품대분류       구매수량
# 13    채소  196188.74
# 14   축산물  143548.50
# 0     간식  135207.00
# 4     반찬  107232.00
# 7     수산   54590.40

# %%
result1.sort_values(by='구매수량',ascending = False).head() #reset_index() 안쓰면 이렇게됨
# Out:
#             구매수량
# 물품대분류
# 채소     196188.74
# 축산물    143548.50
# 간식     135207.00
# 반찬     107232.00
# 수산      54590.40

# %%
sns.barplot(data=result2,x='물품대분류',y='구매수량')

# %%
sns.barplot(data=result2, x='물품대분류',y='구매수량')

# %%
df1_category_top5 = df1[df1['물품대분류'].isin(['채소','축산물','간식','반찬','수산'])]
df1_category_top5.head()
# Out:
#          공급일자 요일  공급월  공급주차        회원번호 조합원상태 물품대분류  물품중분류     물품소분류  \
# 1  2018-01-02  화    1     1  1506656256  정상회원    채소     버섯     느타리버섯
# 2  2018-01-02  화    1     1  1506656256  정상회원   축산물      알       유정란
# 3  2018-01-02  화    1     1  1023108864  정상회원    반찬  두부/유부        두부
# 4  2018-01-02  화    1     1  1476143616  정상회원    간식      빵  식빵, 식사대용
# 5  2018-01-02  화    1     1   716128320  정상회원   축산물      알       유정란
#
#                 물품명  구매수량 주소-구  주소-동 성별    연령    연령대  구매금액 구매매장  반품_원거래일자  \
# 1       느타리버섯(300g)   1.0  수지구  풍덕천동  여  36.0  30대이하  4977  매장C       NaN
# 2  유정란/매장용(10알/국내산)   1.0  수지구  풍덕천동  여  36.0  30대이하  7083  매장C       NaN
# 3         연두부(100g)   1.0  수지구  풍덕천동  여  36.0  30대이하   766  매장C       NaN
# 4   아침빵(240g/8개)/매장   1.0  수지구  풍덕천동  여  34.0  30대이하  4403  매장C       NaN
# 5  유정란/매장용(10알/국내산)   1.0  수지구  풍덕천동  여  51.0    50대  7083  매장C       NaN
#
#     구매시각
# 1  10:05
# 2  10:05
# 3  10:08
# 4  10:09
# 5  10:10

# %%
df2 = pd.pivot_table(data=df1_category_top5, index='공급월',values='구매금액',aggfunc='sum').reset_index()

# %%
sns.lineplot(data = df2,x='공급월',y='구매금액')   #4월에 많이 안팔림 ---> daily report 데일리 리포트
